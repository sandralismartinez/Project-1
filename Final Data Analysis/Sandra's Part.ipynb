# %% [markdown]
# # All States Multiple Box Plots

# %% [markdown]
# # Total Deaths vs. COVID-19 Deaths for Age Group 0-54 years old

# %% [markdown]
# # Total Deaths vs. COVID-19 Deaths for Age Group 55-64 years old

# %% [markdown]
# # Total Deaths vs. COVID-19 Deaths for Age Group 65 years and older

# %% [markdown]
# # Total Deaths vs. Pneumonia and COVID-19 Deaths for Age Group 0-54 years old

# %% [markdown]
# # Total Deaths vs. Pneumonia and COVID-19 Deaths for Age Group 55-64 years old

# %% [markdown]
# # Total Deaths vs. Pneumonia and COVID-19 Deaths for Age Group 65 years and older
